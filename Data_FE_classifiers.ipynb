# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import math, os, pathlib
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE, LocallyLinearEmbedding,MDS
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_auc_score, roc_curve
import itertools

# %%
data = pd.read_csv(r'/content/Brain_GSE50161.csv')
data
# Out:
#      samples                   type  1007_s_at   1053_at     117_at    121_at  \
# 0        834             ependymoma  12.498150  7.604868   6.880934  9.027128
# 1        835             ependymoma  13.067436  7.998090   7.209076  9.723322
# 2        836             ependymoma  13.068179  8.573674   8.647684  9.613002
# 3        837             ependymoma  12.456040  9.098977   6.628784  8.517677
# 4        838             ependymoma  12.699958  8.800721  11.556188  9.166309
# ..       ...                    ...        ...       ...        ...       ...
# 125      959  pilocytic_astrocytoma  12.658228  8.843270   7.672655  9.125912
# 126      960  pilocytic_astrocytoma  12.812823  8.510550   8.729699  9.104402
# 127      961  pilocytic_astrocytoma  12.706991  8.795721   7.772359  8.327273
# 128      962  pilocytic_astrocytoma  12.684593  8.293938   7.228186  8.494428
# 129      963  pilocytic_astrocytoma  12.397722  8.843524   8.825100  8.551541
#
# ...

# %%
data.type.unique()
# Out:
# array(['ependymoma', 'glioblastoma', 'medulloblastoma', 'normal',
#        'pilocytic_astrocytoma'], dtype=object)

# %%
Target = {k: v for k, v in zip(['ependymoma', 'glioblastoma', 'medulloblastoma', 'normal', 'pilocytic_astrocytoma'], list(range(len(['ependymoma', 'glioblastoma', 'medulloblastoma', 'normal', 'pilocytic_astrocytoma']))))}
Target
# Out:
# {'ependymoma': 0,
#  'glioblastoma': 1,
#  'medulloblastoma': 2,
#  'normal': 3,
#  'pilocytic_astrocytoma': 4}

# %%
for i in range(data.shape[0]):
    data.iloc[i, 1] = Target[data.iloc[i, 1]]

# %%
data
# Out:
#      samples type  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0        834    0  12.498150  7.604868   6.880934  9.027128   4.176175
# 1        835    0  13.067436  7.998090   7.209076  9.723322   4.826126
# 2        836    0  13.068179  8.573674   8.647684  9.613002   4.396581
# 3        837    0  12.456040  9.098977   6.628784  8.517677   4.154847
# 4        838    0  12.699958  8.800721  11.556188  9.166309   4.165891
# ..       ...  ...        ...       ...        ...       ...        ...
# 125      959    4  12.658228  8.843270   7.672655  9.125912   5.495477
# 126      960    4  12.812823  8.510550   8.729699  9.104402   3.967228
# 127      961    4  12.706991  8.795721   7.772359  8.327273   6.329383
# 128      962    4  12.684593  8.293938   7.228186  8.494428   6.049414
# 129      963    4  12.397722  8.843524   8.825100  8.551541   5.002072
#
#       1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# ...

# %%
x = np.array(data.iloc[:, 2:])
y = np.asarray(data.iloc[:, 1]).astype('int64')

# %%
embedding = LocallyLinearEmbedding(n_components=5, eigen_solver='dense')
x_lle = embedding.fit_transform(x)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x_lle,y,train_size=0.70, random_state=2)

# %%
#SVM MODEL

model_svm = SVC(random_state=1)
model_svm.fit(X_train, Y_train)
y_pred_svm = model_svm.predict(X_test)
print(classification_report(Y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        21
#            1       0.50      1.00      0.67         5
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         3
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.87        39
#    macro avg       0.70      0.79      0.73        39
# weighted avg       0.83      0.87      0.84        39
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
#===========================CONSTRUCTING THE CONFUSION MATRIX=============================#
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Reds):
    
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
cm = confusion_matrix(Y_test, y_pred_svm)
target_names = ["ependymoma", "glioblastoma", "medulloblastoma", "normal", "pilocytic_astrocytoma"]
plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion Matrix')
accuracy_score(Y_test, y_pred_svm)
# Out:
# 0.8717948717948718

# %%
model_KNN = KNeighborsClassifier()
model_KNN.fit(X_train, Y_train)
y_pred_KNN = model_KNN.predict(X_test)
print(classification_report(Y_test, y_pred_KNN))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        21
#            1       0.83      1.00      0.91         5
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.97        39
#    macro avg       0.97      0.99      0.98        39
# weighted avg       0.98      0.97      0.98        39

# %%
#===========================CONSTRUCTING THE CONFUSION MATRIX=============================#
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
cm = confusion_matrix(Y_test, y_pred_KNN)
target_names = ["ependymoma", "glioblastoma", "medulloblastoma", "normal", "pilocytic_astrocytoma"]
plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion Matrix')
accuracy_score(Y_test, y_pred_KNN)
# Out:
# 0.9743589743589743

# %%
#RandomForestClassifier(ensemble) model

model_RFC = RandomForestClassifier(random_state = 1)
model_RFC.fit(X_train, Y_train)
y_pred_RFC = model_RFC.predict(X_test)
print(classification_report(Y_test, y_pred_RFC))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        21
#            1       0.71      1.00      0.83         5
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         3
#            4       1.00      0.75      0.86         4
#
#     accuracy                           0.95        39
#    macro avg       0.94      0.94      0.93        39
# weighted avg       0.96      0.95      0.95        39

# %%
#===========================CONSTRUCTING THE CONFUSION MATRIX=============================#
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Greens):
    
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
cm = confusion_matrix(Y_test, y_pred_RFC)
target_names = ["ependymoma", "glioblastoma", "medulloblastoma", "normal", "pilocytic_astrocytoma"]
plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion Matrix')
accuracy_score(Y_test, y_pred_RFC)
# Out:
# 0.9487179487179487
